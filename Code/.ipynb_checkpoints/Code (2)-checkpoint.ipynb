# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import math
#from pandas_profiling import ProfileReport
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
import seaborn as sns
import re

# %% [markdown]
# ## Importing Data

# %%
#df = pd.read_csv(r'D:\All_Docs\Masters\CS 584 Machine Learning\Project\Data\vehicles.csv', index_col=0)
df = pd.read_csv(r'C:\Users\venka\Desktop\COURSE\CourseWork\Spring2021\ML\Project\vehicles.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          id                                                url  \
# 0           0  7240372487  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1           1  7240309422  https://auburn.craigslist.org/cto/d/auburn-201...
# 2           2  7240224296  https://auburn.craigslist.org/cto/d/auburn-200...
# 3           3  7240103965  https://auburn.craigslist.org/cto/d/lanett-tru...
# 4           4  7239983776  https://auburn.craigslist.org/cto/d/auburn-200...
#
#    region                     region_url  price    year manufacturer  \
# 0  auburn  https://auburn.craigslist.org  35990  2010.0    chevrolet
# 1  auburn  https://auburn.craigslist.org   7500  2014.0      hyundai
# 2  auburn  https://auburn.craigslist.org   4900  2006.0          bmw
# 3  auburn  https://auburn.craigslist.org   2000  1974.0    chevrolet
# 4  auburn  https://auburn.craigslist.org  19500  2005.0         ford
#
#                   model  condition  ... drive       size    type paint_color  \
# 0  corvette grand sport       good  ...   rwd        NaN   other         NaN
# 1                sonata  excellent  ...   fwd        NaN   sedan         NaN
# 2               x3 3.0i       good  ...   NaN        NaN     SUV        blue
# 3                  c-10       good  ...   rwd  full-size  pickup        blue
# 4           f350 lariat  excellent  ...   4wd  full-size  pickup        blue
#
#                                            image_url  \
# 0  https://images.craigslist.org/00N0N_ipkbHVZYf4...
# 1  https://images.craigslist.org/00s0s_gBHYmJ5o7y...
# 2  https://images.craigslist.org/00B0B_5zgEGWPOrt...
# 3  https://images.craigslist.org/00M0M_6o7KcDpArw...
# 4  https://images.craigslist.org/00p0p_b95l1EgUfl...
#
#                                          description state        lat  \
# 0  Carvana is the safer way to buy a car During t...    al  32.590000
# 1  I'll move to another city and try to sell my c...    al  32.547500
# 2  Clean 2006 BMW X3 3.0I.  Beautiful and rare Bl...    al  32.616807
# 3  1974 chev. truck (LONG BED) NEW starter front ...    al  32.861600
# 4  2005 Ford F350 Lariat (Bullet Proofed). This t...    al  32.547500
#
#         long              posting_date
# 0 -85.480000  2020-12-02T08:11:30-0600
# 1 -85.468200  2020-12-02T02:11:50-0600
# 2 -85.464149  2020-12-01T19:50:41-0600
# 3 -85.216100  2020-12-01T15:54:45-0600
# 4 -85.468200  2020-12-01T12:53:56-0600
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458213 entries, 0 to 458212
# Data columns (total 26 columns):
# Unnamed: 0      458213 non-null int64
# id              458213 non-null int64
# url             458213 non-null object
# region          458213 non-null object
# region_url      458213 non-null object
# price           458213 non-null int64
# year            457163 non-null float64
# manufacturer    439993 non-null object
# model           453367 non-null object
# condition       265273 non-null object
# cylinders       287073 non-null object
# fuel            454976 non-null object
# odometer        402910 non-null float64
# title_status    455636 non-null object
# transmission    455771 non-null object
# VIN             270664 non-null object
# drive           324025 non-null object
# size            136865 non-null object
# type            345475 non-null object
# paint_color     317370 non-null object
# image_url       458185 non-null object
# description     458143 non-null object
# state           458213 non-null object
# lat             450765 non-null float64
# long            450765 non-null float64
# posting_date    458185 non-null object
# dtypes: float64(4), int64(3), object(19)
# memory usage: 90.9+ MB

# %%
df = df.drop(columns=['Unnamed: 0','id', 'url', 'region', 'region_url', 'VIN', 'image_url','state', 'lat', 'long', 'posting_date'])
#df = df.drop(columns=['id', 'url', 'region', 'region_url', 'VIN', 'image_url', 'description', 'state', 'lat', 'long', 'posting_date'])

# %%
df.describe()
# Out:
#               price           year      odometer
# count  4.582130e+05  457163.000000  4.029100e+05
# mean   4.042093e+04    2010.746067  1.016698e+05
# std    8.194599e+06       8.868136  3.228623e+06
# min    0.000000e+00    1900.000000  0.000000e+00
# 25%    4.900000e+03    2008.000000  4.087700e+04
# 50%    1.099500e+04    2013.000000  8.764100e+04
# 75%    2.149500e+04    2016.000000  1.340000e+05
# max    3.615215e+09    2021.000000  2.043756e+09

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Checking for Null values

# %%
for i in df.columns:
    if not df[i].isnull().values.any():
        print(i)
# Out:
# price

# %% [markdown]
# condition
# cylinder
# fuel
# title

# %%
sns.heatmap(df.corr())
plt.show()

# %%
df = df.dropna(axis = 0, subset = ['year'])

# %%
sns.distplot(df.year, kde = False)

# %%
sns.boxplot(df.year)

# %%
df = df[(df.year > 1995)]

# %%
sns.boxplot(df.year)

# %%
df['manufacturer'].isna().sum()
# Out:
# 14655

# %%
manufacturers = df["manufacturer"].value_counts().div(len(df)).mul(100)
manufactuters_TOP20 = manufacturers[:20]

plt.figure(figsize=(16,8))
sns.barplot(x=manufactuters_TOP20.index, y=manufactuters_TOP20.values)
plt.title("20 most popular manufactureres in the USA")
plt.ylabel("Popularity in %")
plt.xticks(rotation=90)
plt.show()

# %%
df['manufacturer'] = df['manufacturer'].fillna("unknown")

# %%
df['model'].isna().sum()
# Out:
# 3752

# %%
df[df['model'] == '$$ CASH 4 JUNK CARS']
# Out:
#         price    year manufacturer                model condition cylinders  \
# 349439   1500  2000.0      unknown  $$ CASH 4 JUNK CARS   salvage     other
# 350064   1000  2000.0      unknown  $$ CASH 4 JUNK CARS   salvage     other
# 350159   1000  2000.0      unknown  $$ CASH 4 JUNK CARS   salvage     other
#
#        fuel  odometer title_status transmission drive size type paint_color  \
# 349439  gas       NaN      salvage        other   fwd  NaN  NaN         NaN
# 350064  gas       NaN      salvage        other   fwd  NaN  NaN         NaN
# 350159  gas       NaN      salvage        other   fwd  NaN  NaN         NaN
#
#                                               description
# 349439  I pay cash for junk cars and unwanted vehicles...
# 350064  I pay cash for junk cars and unwanted vehicles...
# 350159  I pay cash for junk cars and unwanted vehicles...

# %%
df['model'] = df['model'].replace(['$$ CASH 4 JUNK CARS'],'Junk Cars')

# %%
models = df["model"].value_counts().div(len(df)).mul(100)
models_TOP20 = models[:20]

plt.figure(figsize=(16,8))
sns.barplot(x=models_TOP20.index, y=models_TOP20.values)
plt.title("20 most popular models in the USA")
plt.ylabel("Popularity in %")
plt.xticks(rotation=90)
plt.show()

# %%
df['model'] = df['model'].fillna('unknown')

# %%
sns.boxplot(df['odometer'])
plt.show()

# %%
df = df[(df.odometer < 250000) & (df.odometer > 10)]

# %%
sns.boxplot(df['odometer'])

# %%
df[df["condition"]=="new"]["condition"]="like new"
# Out:
# C:\Users\venka\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
odo_mean_excellent=df[df['condition'] == 'excellent']['odometer'].mean()
odo_mean_good=df[df['condition'] == 'good']['odometer'].mean()
odo_mean_salvage=df[df['condition'] == 'salvage']['odometer'].mean()
odo_mean_fair=df[df['condition'] == 'fair']['odometer'].mean()
odo_mean_like_new=df[df['condition'] == 'like new']['odometer'].mean()

# %%
df.loc[df['odometer'] <= odo_mean_like_new, 'condition'] = df.loc[df['odometer'] <= odo_mean_like_new, 'condition'].fillna('like new')

# %%
df.loc[df['odometer'] >= odo_mean_fair, 'condition'] = df.loc[df['odometer'] >= odo_mean_fair, 'condition'].fillna('fair')

# %%
df.loc[((df['odometer'] > odo_mean_like_new) & 
       (df['odometer'] <= odo_mean_excellent)), 'condition'] = df.loc[((df['odometer'] > odo_mean_like_new) & 
       (df['odometer'] <= odo_mean_excellent)), 'condition'].fillna('excellent')

# %%
df.loc[((df['odometer'] > odo_mean_excellent) & 
       (df['odometer'] <= odo_mean_good)), 'condition'] = df.loc[((df['odometer'] > odo_mean_excellent) & 
       (df['odometer'] <= odo_mean_good)), 'condition'].fillna('good')

# %%
df.loc[((df['odometer'] > odo_mean_good) & 
       (df['odometer'] <= odo_mean_fair)), 'condition'] = df.loc[((df['odometer'] > odo_mean_good) & 
       (df['odometer'] <= odo_mean_fair)), 'condition'].fillna('salvage')

# %%
df.cylinders.isna().sum()
# Out:
# 128249

# %%
sns.barplot(y=df['cylinders'].index, x=df['cylinders'].values)
plt.show()

# %%
df['cylinders'].value_counts()
# Out:
# 6 cylinders     94858
# 4 cylinders     85966
# 8 cylinders     68036
# 5 cylinders      1778
# 10 cylinders     1377
# other             756
# 3 cylinders       426
# 12 cylinders      135
# Name: cylinders, dtype: int64

# %%
df['cylinders']=df['cylinders'].fillna(df['cylinders'].mode()[0])

# %%
df['cylinders'].isna().sum()
# Out:
# 0

# %%
sns.barplot(y=df['fuel'].index, x=df['fuel'].values)
plt.show()

# %%
df.fuel.isna().sum()
# Out:
# 2172

# %%
df['fuel']=df['fuel'].fillna(df['fuel'].mode()[0])

# %%
df.fuel.isna().sum()
# Out:
# 0

# %%
df['title_status'].isna().sum()
# Out:
# 1582

# %%
sns.barplot(y=df['title_status'].index, x=df['title_status'].values)
plt.show()

# %%
df['title_status']=df['title_status'].fillna(df['title_status'].mode()[0])

# %%
df.title_status.isna().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    price    year manufacturer                  model  condition    cylinders  \
# 0  35990  2010.0    chevrolet   corvette grand sport       good  8 cylinders
# 1   7500  2014.0      hyundai                 sonata  excellent  4 cylinders
# 2   4900  2006.0          bmw                x3 3.0i       good  6 cylinders
# 4  19500  2005.0         ford            f350 lariat  excellent  8 cylinders
# 5  29590  2016.0       toyota  tacoma double cab sr5       good  6 cylinders
#
#      fuel  odometer title_status transmission drive       size    type  \
# 0     gas   32742.0        clean        other   rwd        NaN   other
# 1     gas   93600.0        clean    automatic   fwd        NaN   sedan
# 2     gas   87046.0        clean    automatic   NaN        NaN     SUV
# 4  diesel  116000.0         lien    automatic   4wd  full-size  pickup
# 5     gas   33290.0        clean        other   NaN        NaN  pickup
#
#   paint_color                                        description
# 0         NaN  Carvana is the safer way to buy a car During t...
# 1         NaN  I'll move to another city and try to sell my c...
# 2        blue  Clean 2006 BMW X3 3.0I.  Beautiful and rare Bl...
# 4        blue  2005 Ford F350 Lariat (Bullet Proofed). This t...
# 5         red  Carvana is the safer way to buy a car During t...

# %%
df['transmission'].shape
# Out:
# (381581,)

# %%
df.shape
# Out:
# (381581, 15)

# %%
df[df.isnull().any(axis=1)]
# Out:
#         price    year manufacturer                        model  condition  \
# 0       35990  2010.0    chevrolet         corvette grand sport       good
# 1        7500  2014.0      hyundai                       sonata  excellent
# 2        4900  2006.0          bmw                      x3 3.0i       good
# 5       29590  2016.0       toyota        tacoma double cab sr5       good
# 6       39990  2012.0         ford   mustang shelby gt500 coupe       good
# ...       ...     ...          ...                          ...        ...
# 458203  14590  2016.0          bmw              i3 hatchback 4d       good
# 458205  20950  2015.0         jeep  grand cherokee overland 4x4    salvage
# 458206   5300  2013.0    chevrolet                      captiva  excellent
# 458207  19950  2017.0         audi  a4 premium plus quattro awd    salvage
# 458212  22900  2008.0      unknown           International 4300       fair
#
#           cylinders      fuel  odometer title_status transmission drive size  \
# 0       8 cylinders       gas   32742.0        clean        other   rwd  NaN
# 1       4 cylinders       gas   93600.0        clean    automatic   fwd  NaN
# 2       6 cylinders       gas   87046.0        clean    automatic   NaN  NaN
# 5       6 cylinders       gas   33290.0        clean        other   NaN  NaN
# 6       8 cylinders       gas    9692.0        clean        other   rwd  NaN
# ...             ...       ...       ...          ...          ...   ...  ...
# 458203  6 cylinders  electric   35533.0        clean        other   rwd  NaN
# 458205  6 cylinders       gas  107907.0        clean    automatic   NaN  NaN
# 458206  4 cylinders       gas  140000.0        clean    automatic   fwd  NaN
# 458207  6 cylinders       gas  101270.0        clean    automatic   NaN  NaN
# 458212  6 cylinders    diesel  164000.0        clean    automatic   NaN  NaN
#
#              type paint_color  \
# 0           other         NaN
# 1           sedan         NaN
# 2             SUV        blue
# 5          pickup         red
# 6           coupe        blue
# ...           ...         ...
# 458203  hatchback         NaN
# 458205        NaN         NaN
# 458206        SUV        blue
# 458207        NaN         NaN
# 458212        NaN         NaN
#
#                                               description
# 0       Carvana is the safer way to buy a car During t...
# 1       I'll move to another city and try to sell my c...
# 2       Clean 2006 BMW X3 3.0I.  Beautiful and rare Bl...
# 5       Carvana is the safer way to buy a car During t...
# 6       Carvana is the safer way to buy a car During t...
# ...                                                   ...
# 458203  Carvana is the safer way to buy a car During t...
# 458205  2015 Jeep Grand Cherokee Overland 4x4 ✔  We TA...
# 458206  2013 Chevy Captiva - Brand new battery - Runs ...
# 458207  2017 Audi A4 Premium Plus Quattro AWD ✔  We TA...
# 458212  *** SHIPPING AVAILABLE DIRECTLY TO YOU. CALL F...
#
# [278132 rows x 15 columns]

# %%
df['transmission'].isnull().any()
# Out:
# True

# %%
print(df['transmission'].isnull().value_counts())
# Out:
# False    379968
# True       1613
# Name: transmission, dtype: int64

# %%
df['transmission'].isna().sum()
# Out:
# 1613

# %%
df[df['transmission'].isna()]
# Out:
#         price    year manufacturer                 model  condition  \
# 2057    19995  2014.0    chevrolet        silverado 1500       fair
# 2602    19995  2014.0    chevrolet        silverado 1500       fair
# 4094    19995  2014.0    chevrolet        silverado 1500       fair
# 5588    19995  2014.0    chevrolet        silverado 1500       fair
# 5769    29588  2019.0         ford              f-150 xl   like new
# ...       ...     ...          ...                   ...        ...
# 456631  11588  2015.0        volvo                   s60   like new
# 456841  29940  2016.0         ford  f350 srw regular cab  excellent
# 456842  51975  2019.0         ford      f550 regular cab   like new
# 456843  29975  2017.0         ford  f350 srw regular cab    salvage
# 457410  69900  2015.0         ford      f-550 super duty  excellent
#
#           cylinders fuel  odometer title_status transmission drive     size  \
# 2057    6 cylinders  gas  194976.0        clean          NaN   NaN      NaN
# 2602    6 cylinders  gas  194976.0        clean          NaN   NaN      NaN
# 4094    6 cylinders  gas  194976.0        clean          NaN   NaN      NaN
# 5588    6 cylinders  gas  194976.0        clean          NaN   NaN      NaN
# 5769    6 cylinders  gas    8421.0        clean          NaN   4wd      NaN
# ...             ...  ...       ...          ...          ...   ...      ...
# 456631  6 cylinders  gas   69199.0        clean          NaN   fwd  compact
# 456841  6 cylinders  gas   92297.0        clean          NaN   NaN      NaN
# 456842  6 cylinders  gas      20.0        clean          NaN   NaN      NaN
# 456843  6 cylinders  gas  107183.0        clean          NaN   NaN      NaN
# 457410  6 cylinders  gas    4524.0        clean          NaN   NaN      NaN
#
#           type paint_color                                        description
# 2057       NaN         NaN  2014 Chevrolet Silverado 1500 - $19,995 \tH & ...
# 2602       NaN         NaN  2014 Chevrolet Silverado 1500 - $19,995 \tH & ...
# 4094       NaN         NaN  2014 Chevrolet Silverado 1500 - $19,995 \tH & ...
# 5588       NaN         NaN  2014 Chevrolet Silverado 1500 - $19,995 \tH & ...
# 5769    pickup       white  2019 Ford F-150 XL  Kendall Ford Lincoln of An...
# ...        ...         ...                                                ...
# 456631   sedan      silver  2015 Volvo S 60 2015.5 4dr Sdn T5 Drive-E FWD ...
# 456841  pickup       white  2016 Ford F350 SRW REGULAR CAB   Century Truck...
# 456842  pickup       white  2019 Ford F550 REGULAR CAB   Century Trucks an...
# 456843     SUV       white  2017 Ford F350 SRW REGULAR CAB   Century Truck...
# 457410     NaN      yellow  2015 Ford F-550 Super Duty 4X4 4dr Crew Cab 17...
#
# [1613 rows x 15 columns]

# %%
df['transmission'].value_counts()
# Out:
# automatic    332915
# other         29778
# manual        17275
# Name: transmission, dtype: int64

# %%
countDesc=0
for index, row in df.iterrows():
    regex=r"[A|a]utomatic|[M|m]anual"
    if row["transmission"]!=row["transmission"]:
            if row["description"]!=row["description"]:
                pass
            else:
                trans=re.findall(regex,row["description"])
                if len(trans)!=0:
                    df.at[index,"transmission"]=trans[0].lower()
    elif row["transmission"]!='automatic' and row["transmission"]!='manual':
            if row["description"]!=row["description"]:
                print(row["description"])
                countDesc+=1
                pass
            else:
                trans=re.findall(regex,row["description"])
                if len(trans)!=0:
                    df.at[index,"transmission"]=trans[0].lower()
print(countDesc)
# Out:
# 0

# %%
df['transmission'].value_counts()
# Out:
# automatic    355096
# manual        22440
# other          2669
# Name: transmission, dtype: int64

# %%
for i in df["transmission"]:
    if i!='automatic' and i!='manual':
        print(i)
# Out:
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# nan
# other
# nan
# nan
# other
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# nan
# other
# nan
# other
# other
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# other
# other
# other
# nan
# nan
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# nan
# nan
# nan
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# nan
# other
# other
# nan
# other
# other
# other
# other
# other
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# nan
# other
# nan
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# nan
# nan
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# other
# nan
# other
# other
# other
# other
# nan
# nan
# other
# nan
# other
# nan
# nan
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# other
# other
# nan
# nan
# nan
# other
# other
# other
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# nan
# other
# nan
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# other
# nan
# nan
# other
# other
# other
# other
# nan
# other
# nan
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# nan
# nan
# nan
# other
# nan
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# nan
# other
# nan
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# other
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# nan
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# nan
# other
# other
# other
# other
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# other
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# other
# nan
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# other
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# other
# nan
# other
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# nan
# nan
# other
# nan
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# nan
# other
# other
# nan
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# nan
# other
# nan
# other
# nan
# other
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# nan
# other
# nan
# other
# other
# other
# nan
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# nan
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# nan
# other
# other
# nan
# nan
# other
# nan
# nan
# other
# other
# nan
# nan
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# other
# nan
# nan
# nan
# other
# nan
# nan
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# nan
# other
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# nan
# other
# nan
# nan
# nan
# other
# other
# nan
# nan
# nan
# other
# other
# nan
# other
# other
# other
# nan
# nan
# other
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# nan
# nan
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# nan
# other
# other
# nan
# nan
# other
# other
# nan
# nan
# nan
# other
# nan
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# nan
# nan
# other
# other
# other
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# nan
# nan
# other
# nan
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# nan
# other
# other
# nan
# nan
# nan
# other
# other
# nan
# other
# nan
# other
# other
# other
# nan
# nan
# nan
# other
# other
# nan
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# nan
# other
# other
# other
# other
# nan
# other
# other
# other
# nan
# nan
# other
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# nan
# other
# nan
# nan
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# other
# other
# nan
# other
# nan
# nan
# other
# other
# nan
# nan
# nan
# other
# other
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# other
# other
# other
# nan
# nan
# nan
# other
# other
# nan
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# nan
# other
# other
# nan
# other
# nan
# other
# nan
# nan
# other
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# nan
# other
# other
# other
# nan
# nan
# other
# nan
# other
# other
# other
# nan
# other
# nan
# other
# other
# nan
# nan
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# nan
# other
# nan
# other
# other
# other
# other
# nan
# other
# other
# nan
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# nan
# other
# nan
# other
# nan
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# nan
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# nan
# nan
# nan
# other
# other
# nan
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# nan
# other
# nan
# other
# other
# other
# nan
# other
# nan
# other
# other
# other
# other
# nan
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# nan
# other
# other
# other
# other
# other
# nan
# other
# other
# nan
# other
# other
# nan
# nan
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# nan
# nan
# other
# nan
# nan
# other
# other
# nan
# other
# nan
# nan
# other
# nan
# nan
# nan
# nan
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# other
# nan
# other
# other
# other
# other
# other
# other
# other
# other
# other
# nan
# nan
# nan
# nan
# other
# nan
# other

# %%
df['drive'].value_counts()
# Out:
# 4wd    125878
# fwd    112488
# rwd     50530
# Name: drive, dtype: int64

# %%
df['size'].value_counts()
# Out:
# full-size      58948
# mid-size       37045
# compact        19238
# sub-compact     3118
# Name: size, dtype: int64

# %%
df['type'].value_counts()
# Out:
# sedan          85138
# SUV            73463
# pickup         39218
# truck          30654
# other          21831
# coupe          16114
# hatchback      15457
# wagon           9788
# van             8614
# mini-van        5626
# convertible     5326
# bus              564
# offroad          377
# Name: type, dtype: int64

# %%
df[df["transmission"]=='other']
# Out:
#         price    year manufacturer              model condition    cylinders  \
# 373     25900  2013.0       toyota             tundra      good  8 cylinders
# 374      7897  2007.0        buick           lacrosse      fair  6 cylinders
# 449     10987  2010.0        buick           lacrosse   salvage  6 cylinders
# 481     12987  2013.0         ford             escape   salvage  4 cylinders
# 482     17897  2016.0      hyundai             sonata  like new  4 cylinders
# ...       ...     ...          ...                ...       ...          ...
# 456540  26800  2019.0       subaru            outback  like new  6 cylinders
# 456560  26300  2019.0       subaru          crosstrek  like new  6 cylinders
# 456571  26300  2020.0       subaru           forester  like new  6 cylinders
# 456874  36950  2012.0         ford              f-550      fair  6 cylinders
# 458148   3500  2001.0      unknown  32' 2 car trailer      good  6 cylinders
#
#           fuel  odometer title_status transmission drive       size   type  \
# 373        gas  107690.0        clean        other   NaN  full-size  truck
# 374        gas  176354.0        clean        other   fwd        NaN  sedan
# 449        gas  120950.0        clean        other   fwd        NaN  sedan
# 481        gas  122136.0        clean        other   fwd        NaN    SUV
# 482        gas   43097.0        clean        other   fwd        NaN  sedan
# ...        ...       ...          ...          ...   ...        ...    ...
# 456540   other   13806.0        clean        other   NaN        NaN    NaN
# 456560   other   13967.0        clean        other   NaN        NaN    NaN
# 456571   other    2972.0        clean        other   NaN        NaN    NaN
# 456874  diesel  246844.0        clean        other   NaN        NaN  other
# 458148   other     100.0        clean        other   NaN  full-size  other
#
#        paint_color                                        description
# 373           grey  2013 Toyota Tundra Tundra-Grade CrewMax 5.7L F...
# 374          white  2007 Buick LaCrosse 4dr Sdn CXL -- $7,897     ...
# 449            red  This 2010 Buick LaCrosse 4dr Sdn CXL 3.0L FWD ...
# 481          black  2013 Ford Escape FWD 4dr Titanium -- $12,987  ...
# 482           grey  This 2016 Hyundai Sonata 4dr Sdn 2.4L Sport ha...
# ...            ...                                                ...
# 456540         NaN  Georgetown Subaru | Call us at 888-494-4077Tra...
# 456560         NaN  Georgetown Subaru | Call us at 888-494-4077Ext...
# 456571         NaN  Georgetown Subaru | Call us at 888-494-4077Mak...
# 456874       white  OT Truck & Tractor LLCAsk for: Sales☎ (405) 99...
# 458148       black  32' 2 Car Hauler Trailer with electric brakes ...
#
# [2669 rows x 15 columns]

# %%
df['type'].isna().sum()
# Out:
# 69411

# %%
plt.figure(figsize=(15,10)) 
sns.barplot(y=df['type'].index, x=df['type'].values)
plt.show()

# %%
df['type'].value_counts().sum()
# Out:
# 312170

# %%
df.shape
# Out:
# (381581, 15)

# %%
df['type']
# Out:
# 0          other
# 1          sedan
# 2            SUV
# 4         pickup
# 5         pickup
#            ...
# 458208       SUV
# 458209       SUV
# 458210     coupe
# 458211       SUV
# 458212       NaN
# Name: type, Length: 381581, dtype: object

# %%
df["type"] = df["type"].str.lower()

# %%
df['type']
# Out:
# 0          other
# 1          sedan
# 2            suv
# 4         pickup
# 5         pickup
#            ...
# 458208       suv
# 458209       suv
# 458210     coupe
# 458211       suv
# 458212       NaN
# Name: type, Length: 381581, dtype: object

# %%
df["type"] = df["type"].str.lower()
for index, row in df.iterrows():
    if row["type"]!=row["type"]:
        regex=r"sedan|pickup|truck|coupe|hatchback|wagon|van|convertible|mini-van|offroad|bus"
        if row["description"]!=row["description"]:
            pass
        else:
            typecar=re.findall(regex,row["description"])
            if len(typecar)!=0:
                df.at[index,"type"]=typecar[0].lower()

# %%
df['type'].value_counts().sum()
# Out:
# 337285

# %%
#plt.figure(figsize=(10,10)) 
for i in range(int(min(df['year'])),int(max(df['year'])+1),5):
    dftemp=df[df['year']>=i]
    sns.barplot(y=dftemp['drive'].index, x=dftemp['drive'].values)
    plt.show()

# %%
df.head()
# Out:
#    price    year manufacturer                  model  condition    cylinders  \
# 0  35990  2010.0    chevrolet   corvette grand sport       good  8 cylinders
# 1   7500  2014.0      hyundai                 sonata  excellent  4 cylinders
# 2   4900  2006.0          bmw                x3 3.0i       good  6 cylinders
# 4  19500  2005.0         ford            f350 lariat  excellent  8 cylinders
# 5  29590  2016.0       toyota  tacoma double cab sr5       good  6 cylinders
#
#      fuel  odometer title_status transmission drive       size    type  \
# 0     gas   32742.0        clean    automatic   rwd        NaN   other
# 1     gas   93600.0        clean    automatic   fwd        NaN   sedan
# 2     gas   87046.0        clean    automatic   NaN        NaN     suv
# 4  diesel  116000.0         lien    automatic   4wd  full-size  pickup
# 5     gas   33290.0        clean    automatic   NaN        NaN  pickup
#
#   paint_color                                        description
# 0         NaN  Carvana is the safer way to buy a car During t...
# 1         NaN  I'll move to another city and try to sell my c...
# 2        blue  Clean 2006 BMW X3 3.0I.  Beautiful and rare Bl...
# 4        blue  2005 Ford F350 Lariat (Bullet Proofed). This t...
# 5         red  Carvana is the safer way to buy a car During t...

# %%
min(df['year'])
# Out:
# 1996.0

# %%
max(df['year'])
# Out:
# 2021.0

# %%
print(df.shape)
for i in range(int(min(df['year'])),int(max(df['year'])+1),5):
    dftemp=df[df['year']>=i]
    print(i,dftemp.shape)
# Out:
# (381581, 15)
# 1996 (381581, 15)
# 2001 (371749, 15)
# 2006 (336483, 15)
# 2011 (261143, 15)
# 2016 (124342, 15)
# 2021 (269, 15)

# %%
for i in range(int(min(df['year'])),int(max(df['year'])+1),5):
    dftemp=df[df['year']>=i]
    print(dftemp[dftemp['drive']=='fwd']['price'].median())

# %%
print(dftemp[dftemp['drive']=='fwd']['price'].median())
# Out:
# 18638.0

# %%
print(dftemp[dftemp['drive']=='rwd']['price'].median())
# Out:
# 38995.0

# %%
print(dftemp[dftemp['drive']=='4wd']['price'].median())
# Out:
# 46936.0

# %%
print(dftemp[dftemp['drive']=='fwd']['price'].mean())
print(dftemp[dftemp['drive']=='rwd']['price'].mean())
print(dftemp[dftemp['drive']=='4wd']['price'].mean())
# Out:
# 18292.8
# 36789.10526315789
# 36785.39473684211

# %%
df['size'].value_counts().sum()
# Out:
# 118349

# %%
df['size'].value_counts()
# Out:
# full-size      58948
# mid-size       37045
# compact        19238
# sub-compact     3118
# Name: size, dtype: int64

# %%
print(dftemp[dftemp['size']=='full-size']['price'].mean())
print(dftemp[dftemp['size']=='mid-size']['price'].mean())
print(dftemp[dftemp['size']=='compact']['price'].mean())
print(dftemp[dftemp['size']=='sub-compact']['price'].mean())
# Out:
# 43071.142857142855
# 42706.333333333336
# 6486.5
# 410.0
